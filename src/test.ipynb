# %% [markdown]
# Upload Datasets

# %%
import pandas as pd
rt_df = pd.read_csv('datatata/AggregatedData_AustralianSpeciesOccurrences.csv')
soc_df = pd.read_csv('datata/blabal.csv')
eco_df = pd.read_csv('datatata/Descriptors-Cost.csv')

# %% [markdown]
# Clean data

# %%
eco_df.head()

# %%
rt_df.dtypes

# %%
rt_df[['year'], ['occurenceCount']] = pd.to_numeric(rt_df[['year'], ['occurrenceCount']])
rt_df = rt_df[rt_df['year'] >= 1960]
rt_df.head()

# %%
for col in rt_df:
    if col.__contains__('Felis catus'):
        print(col)
    else:
        None
